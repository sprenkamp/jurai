# %%
import oldp_client 

conf = oldp_client.Configuration()

conf.api_key['Authorization'] = '73efd304f9ecb4d715768ca19523e87f86c8ec83'  # TODO Replace this with your API key
conf.api_key_prefix['Authorization'] = 'Token'

api_client = oldp_client.ApiClient(conf)

laws_api = oldp_client.LawsApi(api_client)

#courts = courts_api.courts_list().results
thread = laws_api.laws_list(async_req=True)
result = thread.get()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jx/2l7p1chd2l7djbz_8s3s_4z80000gn/T/ipykernel_42113/4182647399.py in ?()
#      14 result = thread.get()
#      15
#      16 import pandas as pd
#      17
# ---> 18 df = pd.DataFrame(result)
#      19 df.head()
#
# ~/miniconda3/envs/jurai/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     837                 )
#     838         # For data is scalar
#     839         else:
#     840             if index is None or columns is None:
# --> 841                 raise ValueError("DataFrame constructor not properly called!")
#     842
#     843             index = ensure_index(index)
#     844             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
result.results
# Out:
# [{'book': 1369,
#   'content': '<P>Auf Grund des &#167; 4 Absatz 1 in Verbindung mit &#167; 5 des '
#              'Berufsbildungsgesetzes, von denen &#167; 4 Absatz 1 durch Artikel '
#              '232 Nummer 1 der Verordnung vom 31. Oktober 2006 (BGBl. I S. '
#              '2407) ge&#228;ndert worden ist, verordnet das Bundesministerium '
#              'f&#252;r Wirtschaft und Technologie im Einvernehmen mit dem '
#              'Bundesministerium f&#252;r Bildung und Forschung:</P>\n'
#              '        ',
#   'slug': 'eingangsformel',
#   'title': ''},
#  {'book': 1747,
#   'content': '<P>Der Bundestag hat mit Zustimmung des Bundesrates das folgende '
#              'Gesetz beschlossen:</P>\n'
#              '        ',
#   'slug': 'eingangsformel',
#   'title': ''},
#  {'book': 1950,
#   'content': '<P>Auf Grund des &#167; 6 Abs. 3 des Gesetzes &#252;ber die '
#              'elektromagnetische Vertr&#228;glichkeit von Betriebsmitteln vom '
#              '26. Februar 2008 (BGBl. I S. 220) verordnet die '
#              'Bundesregierung:</P>\n'
#              '        ',
#   'slug': 'eingangsformel',
#   'title': ''},
#  {'book': 2149,
#   'content': '<P>\n'
#              '             \n'
#              '            <table frame="none" pgwide="1" tocentry="%yes;">\n'
#              '              \n'
#              '\t\n'
#              '              <tgroup align="left" char="" charoff="50" cols="6" '
#              'colsep="0" rowsep="0">\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col1" colnum="1" '
#              'colwidth="5*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col2" colnum="2" '
#              'colwidth="5*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col3" colnum="3" '
#              'colwidth="5*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col4" colnum="4" '
#              'colwidth="5*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col5" colnum="5" '
#              'colwidth="5*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <colspec colname="col6" colnum="6" '
#              'colwidth="80*"/>\n'
#              '                \n'
#              '\t\t\n'
#              '                <tbody valign="top">\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col1" valign="top">Einleitende '
#              'Bestimmungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 1</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Sachlicher und '
#              'pers&#246;nlicher Geltungsbereich</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 2</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Fr&#252;her begangene '
#              'Dienstvergehen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 3</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Akteneinsicht durch den '
#              'Soldaten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 4</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Beteiligung der '
#              'Vertrauensperson</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 5</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Zustellungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 6</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Belehrung &#252;ber '
#              'Rechtsmittel und Rechtsbehelfe</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 7</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Disziplinarbuch</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 8</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Tilgung</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 9</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Ausk&#252;nfte</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 10</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Entsch&#228;digung von '
#              'Zeugen und Sachverst&#228;ndigen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col1" valign="top">Erster Teil</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col2" valign="top">W&#252;rdigung '
#              'besonderer Leistungen durch f&#246;rmliche Anerkennungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 11</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Voraussetzungen und '
#              'Arten der f&#246;rmlichen Anerkennungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 12</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Zust&#228;ndigkeit zum '
#              'Erteilen von f&#246;rmlichen Anerkennungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 13</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Erteilen von '
#              'f&#246;rmlichen Anerkennungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 14</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">R&#252;cknahme von '
#              'f&#246;rmlichen Anerkennungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col1" valign="top">Zweiter Teil</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col2" valign="top">Ahndung von '
#              'Dienstvergehen durch Disziplinarma&#223;nahmen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col3" valign="top">Erster '
#              'Abschnitt</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col4" valign="top">Allgemeine '
#              'Bestimmungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 15</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Disziplinarma&#223;nahmen, '
#              'Ermessensgrundsatz</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 16</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Verh&#228;ltnis der '
#              'Disziplinarma&#223;nahmen zu Strafen und '
#              'Ordnungsma&#223;nahmen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 17</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Zeitablauf</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 18</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Verbot mehrfacher, '
#              'Gebot einheitlicher Ahndung</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 19</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Gnadenrecht</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 20</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Durchsuchung und '
#              'Beschlagnahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 21</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Vorl&#228;ufige '
#              'Festnahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col3" valign="top">Zweiter '
#              'Abschnitt</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col4" valign="top">Die Disziplinarbefugnis '
#              'der Disziplinarvorgesetzten und ihre Aus&#252;bung</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">1.</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">Einfache Disziplinarma&#223;nahmen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 22</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Arten der einfachen '
#              'Disziplinarma&#223;nahmen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 23</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Verweis, strenger '
#              'Verweis</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 24</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Disziplinarbu&#223;e</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 25</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Ausgangsbeschr&#228;nkung</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 26</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Disziplinararrest</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">2.</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">Disziplinarbefugnis</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 27</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" '
#              'valign="top">Disziplinarvorgesetzte</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 28</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Stufen der '
#              'Disziplinarbefugnis</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 29</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Zust&#228;ndigkeit des '
#              'n&#228;chsten Disziplinarvorgesetzten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 30</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Zust&#228;ndigkeit des '
#              'n&#228;chsth&#246;heren Disziplinarvorgesetzten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 31</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Disziplinarbefugnis '
#              'nach dem Dienstgrad</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">3.</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">Aus&#252;bung der Disziplinarbefugnis</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 32</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Ermittlungen des '
#              'Disziplinarvorgesetzten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 33</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Pr&#252;fungspflicht '
#              'des Disziplinarvorgesetzten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 34</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Bindung an '
#              'tats&#228;chliche Feststellungen anderer Entscheidungen</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 35</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Selbst&#228;ndigkeit '
#              'des Disziplinarvorgesetzten</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 36</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Absehen von einer '
#              'Disziplinarma&#223;nahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 37</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Verh&#228;ngen der '
#              'Disziplinarma&#223;nahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 38</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Richtlinien f&#252;r '
#              'das Bemessen der Disziplinarma&#223;nahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 39</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Anrechnung von '
#              'Freiheitsentziehung auf die Disziplinarma&#223;nahme</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 40</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col6" namest="col5" valign="top">Mitwirkung des Richters '
#              'bei der Verh&#228;ngung von Disziplinararrest</entry>\n'
#              '                    \n'
#              '\t\t\t\n'
#              '                  </row>\n'
#              '                  \n'
#              '\t\t\t\n'
#              '                  <row>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'nameend="col3" namest="col1" valign="top">&#167; 41</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
#              'valign="top">&#160;</entry>\n'
#              '                    \n'
#              '\t\t\t\t\n'
#              '                    <entry VJ="1" align="left" colsep="0" '
# ...
#              '                    <entry VJ="1">\n'
#              '                      <B>Stromstrecken mit Meldepflicht oder mit '
#              'Wahrschauregelung</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 12.01</entry>\n'
#              '                    <entry VJ="1">Meldepflicht</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 12.02</entry>\n'
#              '                    <entry VJ="1">Funktion der Lichtwahrschau auf '
#              'der Strecke Oberwesel &#8211; St. Goar</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 12.03</entry>\n'
#              '                    <entry VJ="1">Besondere Regeln f&#252;r die '
#              'Fahrt in der Wahrschaustrecke</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Kapitel 13</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Besondere Bestimmungen f&#252;r den '
#              'Verkehr der Kanalpenichen auf der Strecke Basel bis Schleusen '
#              'Iffezheim</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.01</entry>\n'
#              '                    <entry VJ="1">Anwendungsbereich</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.02</entry>\n'
#              '                    <entry VJ="1">Kennzeichnung der '
#              'Fahrzeuge</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.03</entry>\n'
#              '                    <entry VJ="1">Einsenkungsmarken</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.04</entry>\n'
#              '                    <entry VJ="1">Tiefgangsanzeiger</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.05</entry>\n'
#              '                    <entry VJ="1">Unterscheidungszeichen der '
#              'Anker</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 13.06</entry>\n'
#              '                    <entry VJ="1">Zusammenstellung der '
#              'Verb&#228;nde</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Kapitel 14</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Vorschriften f&#252;r die Reeden auf dem '
#              'Rhein</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.01</entry>\n'
#              '                    <entry VJ="1">Allgemeine '
#              'Bestimmungen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.02</entry>\n'
#              '                    <entry VJ="1">Basel</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.03</entry>\n'
#              '                    <entry VJ="1">Mannheim-Ludwigshafen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.04</entry>\n'
#              '                    <entry VJ="1">Mainz</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.05</entry>\n'
#              '                    <entry VJ="1">Bingen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.06</entry>\n'
#              '                    <entry VJ="1">Bad Salzig</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.07</entry>\n'
#              '                    <entry VJ="1">Koblenz</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.08</entry>\n'
#              '                    <entry VJ="1">Andernach</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.09</entry>\n'
#              '                    <entry VJ="1">Wesseling</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.10</entry>\n'
#              '                    <entry VJ="1">Duisburg-Ruhrort</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.11</entry>\n'
#              '                    <entry VJ="1">(ohne Inhalt)</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.12</entry>\n'
#              '                    <entry VJ="1">Lobith</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 14.13</entry>\n'
#              '                    <entry VJ="1">Ijzendoorn und Haaften</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" namest="col1">\n'
#              '                      <B>Dritter Teil</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" namest="col1">\n'
#              '                      <B>Umweltbestimmungen</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Kapitel 15</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#160;</entry>\n'
#              '                    <entry VJ="1">\n'
#              '                      <B>Gew&#228;sserschutz und '
#              'Abfallbeseitigung auf Fahrzeugen</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.01</entry>\n'
#              '                    <entry VJ="1">Begriffsbestimmungen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.02</entry>\n'
#              '                    <entry VJ="1">Allgemeine '
#              'Sorgfaltspflicht</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.03</entry>\n'
#              '                    <entry VJ="1">Verbot der Einbringung und '
#              'Einleitung</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.04</entry>\n'
#              '                    <entry VJ="1">Sammlung und Behandlung an '
#              'Bord</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.05</entry>\n'
#              '                    <entry VJ="1">&#214;lkontrollbuch, Abgabe an '
#              'Annahmestellen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.06</entry>\n'
#              '                    <entry VJ="1">Sorgfaltspflicht beim '
#              'Bunkern</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.07</entry>\n'
#              '                    <entry VJ="1">(ohne Inhalt)</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.08</entry>\n'
#              '                    <entry '
#              'VJ="1">Bilgenent&#246;lungsboote</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">&#167; 15.09</entry>\n'
#              '                    <entry VJ="1">Anstrich und '
#              'Au&#223;enreinigung der Fahrzeuge</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" namest="col1">\n'
#              '                      <B>Anlagen</B>\n'
#              '                    </entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1" nameend="col2" '
#              'namest="col1">&#160;</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 1:</entry>\n'
#              '                    <entry VJ="1">Unterscheidungsbuchstabe oder '
#              '-buchstabengruppe des Landes, in welchem der Heimat- oder '
#              'Registerort der Fahrzeuge liegt</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 2:</entry>\n'
#              '                    <entry VJ="1">(ohne Inhalt)</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 3:</entry>\n'
#              '                    <entry VJ="1">Bezeichnung der '
#              'Fahrzeuge</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 4:</entry>\n'
#              '                    <entry VJ="1">(ohne Inhalt)</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 5:</entry>\n'
#              '                    <entry VJ="1">(ohne Inhalt)</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 6:</entry>\n'
#              '                    <entry VJ="1">Schallzeichen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 7:</entry>\n'
#              '                    <entry VJ="1">Schiffahrtszeichen</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 8:</entry>\n'
#              '                    <entry VJ="1">Bezeichnung der '
#              'Wasserstra&#223;e</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 9:</entry>\n'
#              '                    <entry VJ="1">Lichtwahrschau Oberwesel '
#              '&#8211; St. Goar Rhein-km 548,50 &#8211; 555,43</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 10:</entry>\n'
#              '                    <entry VJ="1">Muster f&#252;r das '
#              '&#214;lkontrollbuch</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 11:</entry>\n'
#              '                    <entry VJ="1">Daten, die in das Inland AIS '
#              'Ger&#228;t einzugeben sind: Erl&#228;uterungen '
#              '&#8222;Navigationsstatus&#8220; und des Bezugspunktes der '
#              'Positionsinformation auf dem Fahrzeug</entry>\n'
#              '                  </row>\n'
#              '                  <row>\n'
#              '                    <entry VJ="1">Anlage 12:</entry>\n'
#              '                    <entry VJ="1">(weggefallen)</entry>\n'
#              '                  </row>\n'
#              '                </tbody>\n'
#              '              </tgroup>\n'
#              '            </table>\n'
#              '            <!--Ende: BJNR338160994BJNE003303308_01-->\n'
#              '          </P>\n'
#              '        ',
#   'slug': 'inhaltsverzeichnis',
#   'title': ''}]
